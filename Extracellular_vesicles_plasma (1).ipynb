# %%
library(readxl)

# %%
X15_cluster_pathway_category = read_excel("15_cluster_pathway_category_R.xlsx")
X15_cluster_pathway_category
# Out:
# New names:
# * `` -> ...1
#     ...1 Term                                Comparison Fold_Enrichment
# 1    1   Antigen processing and presentation C1                NA
# 2    2   Antigen processing and presentation C2                NA
# 3    3   Antigen processing and presentation C3         10.291441
# 4    4   Antigen processing and presentation C4                NA
# 5    5   Antigen processing and presentation C5                NA
# 6    6   Antigen processing and presentation C6                NA
# 7    7   Antigen processing and presentation C7                NA
# 8    8   Antigen processing and presentation C8                NA
# 9    9   Antigen processing and presentation C9                NA
# 10  10   Antigen processing and presentation C10         4.365896
# 11  11   Antigen processing and presentation C11         2.179725
# 12  12   Antigen processing and presentation C12               NA
# 13  13   Antigen processing and presentation C13               NA
# 14  14   Antigen processing and presentation C14               NA
# 15  15   Antigen processing and presentation C15        12.044379
# 16  16   B cell receptor signaling pathway   C1                NA
# 17  17   B cell receptor signaling pathway   C2                NA
# 18  18   B cell receptor signaling pathway   C3          5.593954
# 19  19   B cell receptor signaling pathway   C4                NA
# 20  20   B cell receptor signaling pathway   C5                NA
# 21  21   B cell receptor signaling pathway   C6                NA
# 22  22   B cell receptor signaling pathway   C7                NA
# 23  23   B cell receptor signaling pathway   C8                NA
# 24  24   B cell receptor signaling pathway   C9                NA
# 25  25   B cell receptor signaling pathway   C10         3.586618
# 26  26   B cell receptor signaling pathway   C11               NA
# 27  27   B cell receptor signaling pathway   C12               NA
# 28  28   B cell receptor signaling pathway   C13               NA
# 29  29   B cell receptor signaling pathway   C14               NA
# 30  30   B cell receptor signaling pathway   C15               NA
# ... ...  ...                                 ...        ...
# 376 376  Spliceosome                         C1                NA
# 377 377  Spliceosome                         C2                NA
# 378 378  Spliceosome                         C3                NA
# 379 379  Spliceosome                         C4                NA
# 380 380  Spliceosome                         C5                NA
# 381 381  Spliceosome                         C6                NA
# 382 382  Spliceosome                         C7                NA
# 383 383  Spliceosome                         C8                NA
# 384 384  Spliceosome                         C9          4.526146
# 385 385  Spliceosome                         C10               NA
# 386 386  Spliceosome                         C11               NA
# 387 387  Spliceosome                         C12               NA
# 388 388  Spliceosome                         C13               NA
# 389 389  Spliceosome                         C14               NA
# 390 390  Spliceosome                         C15               NA
# 391 391  Complement and coagulation cascades C1                NA
# 392 392  Complement and coagulation cascades C2                NA
# 393 393  Complement and coagulation cascades C3          9.443911
# 394 394  Complement and coagulation cascades C4         23.947059
# 395 395  Complement and coagulation cascades C5         29.933824
# 396 396  Complement and coagulation cascades C6         31.066455
# 397 397  Complement and coagulation cascades C7         20.823529
# 398 398  Complement and coagulation cascades C8         53.880882
# 399 399  Complement and coagulation cascades C9                NA
# 400 400  Complement and coagulation cascades C10         2.731604
# 401 401  Complement and coagulation cascades C11               NA
# 402 402  Complement and coagulation cascades C12        26.940441
# 403 403  Complement and coagulation cascades C13               NA
# 404 404  Complement and coagulation cascades C14        47.894118
# 405 405  Complement and coagulation cascades C15         7.368326
#     pvalue       category
# 1             NA Cell-to-cell communication
# 2             NA Cell-to-cell communication
# 3   5.126674e-05 Cell-to-cell communication
# 4             NA Cell-to-cell communication
# 5             NA Cell-to-cell communication
# 6             NA Cell-to-cell communication
# 7             NA Cell-to-cell communication
# 8             NA Cell-to-cell communication
# 9             NA Cell-to-cell communication
# 10  1.149703e-08 Cell-to-cell communication
# 11  5.264793e-02 Cell-to-cell communication
# 12            NA Cell-to-cell communication
# 13            NA Cell-to-cell communication
# 14            NA Cell-to-cell communication
# 15  1.180163e-04 Cell-to-cell communication
# 16            NA Cell-to-cell communication
# 17            NA Cell-to-cell communication
# 18  3.326360e-02 Cell-to-cell communication
# 19            NA Cell-to-cell communication
# 20            NA Cell-to-cell communication
# 21            NA Cell-to-cell communication
# 22            NA Cell-to-cell communication
# 23            NA Cell-to-cell communication
# 24            NA Cell-to-cell communication
# 25  3.371578e-06 Cell-to-cell communication
# 26            NA Cell-to-cell communication
# 27            NA Cell-to-cell communication
# 28            NA Cell-to-cell communication
# 29            NA Cell-to-cell communication
# 30            NA Cell-to-cell communication
# ... ...          ...
# 376           NA DNA replication, RNA transcription and protein translation
# 377           NA DNA replication, RNA transcription and protein translation
# 378           NA DNA replication, RNA transcription and protein translation
# 379           NA DNA replication, RNA transcription and protein translation
# 380           NA DNA replication, RNA transcription and protein translation
# 381           NA DNA replication, RNA transcription and protein translation
# 382           NA DNA replication, RNA transcription and protein translation
# 383           NA DNA replication, RNA transcription and protein translation
# 384 2.113116e-24 DNA replication, RNA transcription and protein translation
# 385           NA DNA replication, RNA transcription and protein translation
# 386           NA DNA replication, RNA transcription and protein translation
# 387           NA DNA replication, RNA transcription and protein translation
# 388           NA DNA replication, RNA transcription and protein translation
# 389           NA DNA replication, RNA transcription and protein translation
# 390           NA DNA replication, RNA transcription and protein translation
# 391           NA Complement and coagulation cascades
# 392           NA Complement and coagulation cascades
# 393 8.326946e-05 Complement and coagulation cascades
# 394 1.059278e-12 Complement and coagulation cascades
# 395 1.597696e-11 Complement and coagulation cascades
# 396 4.008386e-14 Complement and coagulation cascades
# 397 7.011817e-05 Complement and coagulation cascades
# 398 6.115038e-13 Complement and coagulation cascades
# 399           NA Complement and coagulation cascades
# 400 9.790361e-04 Complement and coagulation cascades
# 401           NA Complement and coagulation cascades
# 402 6.548301e-10 Complement and coagulation cascades
# 403           NA Complement and coagulation cascades
# 404 3.099703e-02 Complement and coagulation cascades
# 405 1.595152e-02 Complement and coagulation cascades

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(forcats)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang

# %%
options(repr.plot.width = 9, repr.plot.height =9)
X15_cluster_pathway_category%>% ggplot(aes(x = fct_inorder( Comparison), y = fct_inorder(Term), color = pvalue)) + 
        geom_point(aes(size = Fold_Enrichment)) +
        scale_color_gradient(low="blue", high="red", guide = guide_colorbar(title = "p-value")) +   
        guides(size = guide_legend(title = "Fold Enrichment")) + labs(x = "Clusters") + 
        labs(y = " Pathways") + facet_wrap(~category, scales = "free_y", ncol = 1, strip.position = "top")
# Out:
# Warning message:
# "Removed 350 rows containing missing values (geom_point)."
# plot without title
